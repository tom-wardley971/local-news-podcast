# %%
import sys
sys.path.insert(0, 'src')
from config import SITES
from scraper import scrape_all_sites, scrape_site

# %%
articles = scrape_site(SITES[0])
for a in articles:
    print(a.headline)
    print(a.body[:1000])
    print('----')
# Out:
#   ✅ Example Local News: 10 articles scraped
# Councillor resignation triggers by-election
#
# ----
# Gambling reforms unveiled
#
# ----
# Draft council budget revealed
#
# ----
# Date set for aged care service transition
#
# ----
# Golf course housing plan ‘possible’ – panel
#
# ----
# Plan for parcel locker
# A NEW parcel locker will be installed in Frankston to accommodate online shoppers. Australia Post estimates that online shopping spending is up 13 percent from the year prior, and is…
# ----
# Luxury home show’s filming at odds with homelessness crisis
# By Molly Broadfoot* AS homelessness hits a record-high on the Mornington Peninsula, The Block has begun filming its latest season in Mt Eliza. In an $11m deal to purchase the…
# ----
# Mayor to advise state government
# FRANKSTON mayor Sue Baker will work closely with the local government minister this year after her appointment to the 2026 Local Government Mayor Advisory Panel.  The 11 mayors appointed to…
# ----
# ...
